# %%
import sys
# Utilise le chemin direct vers l'exécutable Python de votre Jupyter
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install transformers torch sentencepiece sacremoses --user

# %%
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer
import torch

# Chargement du modèle et du tokenizer (version 418M paramètres pour un bon ratio vitesse/qualité)
model_name = "facebook/m2m100_418M"
tokenizer = M2M100Tokenizer.from_pretrained(model_name)
model = M2M100ForConditionalGeneration.from_pretrained(model_name)

def translate_logic(text, src_lang="fr", tgt_lang="en"):
    tokenizer.src_lang = src_lang
    encoded_input = tokenizer(text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_input, forced_bos_token_id=tokenizer.get_lang_id(tgt_lang))
    return tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
# Out:
# C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:  63%|######3   | 1.23G/1.94G [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/facebook/m2m100_418M/resolve/refs%2Fpr%2F27/model.safetensors: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# ...

# %%
# Installation des bibliothèques manquantes
# !pip install easyocr openai-whisper transformers sentencepiece gradio torch
